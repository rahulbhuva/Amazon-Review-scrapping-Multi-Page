# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Function to get and return parsed HTML
def get_soup(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup

# Initialize list to store reviews data later on
reviewlist = []

# %%
# Function that sifts through the soup element above, tries to find the tags for the data we want, then appends to the list we initialized
def get_reviews(soup):
    reviews = soup.find_all('div', {'data-hook': 'review'})
    try:
        for item in reviews:
            review = {
            'product': soup.title.text.replace('Amazon.ca:Customer reviews: ', '').strip(), 
            'date': item.find('span', {'data-hook': 'review-date'}).text.strip(),
            'title': item.find('a', {'data-hook': 'review-title'}).text.strip(),
            'rating':  float(item.find('i', {'data-hook': 'review-star-rating'}).text.replace('out of 5 stars', '').strip()),
            'body': item.find('span', {'data-hook': 'review-body'}).text.strip(),
            }
            reviewlist.append(review)
    except:
        pass

# %%
# Function 3: loop through 1:x many pages, or until the css selector found only on the last page is found (when the next page button is greyed)
for x in range(1,20):
    soup = get_soup(f'https://www.amazon.in/Airdopes-141-Playtime-Resistance-Bluetooth/product-reviews/B09N3ZNHTY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber={x}')
    print(f'Getting page: {x}')
    get_reviews(soup)
    print(len(reviewlist))
    if not soup.find('li', {'class': 'a-disabled a-last'}):
        pass
    else:
        break

# Save results to a dataframe, then export as CSV
df = pd.DataFrame(reviewlist)
df.to_csv(r'headphones21.csv', index=False)
print('Fin.')
# Out:
# Getting page: 1
# 10
# Getting page: 2
# 20
# Getting page: 3
# 30
# Getting page: 4
# 40
# Getting page: 5
# 50
# Getting page: 6
# 60
# Getting page: 7
# 70
# Getting page: 8
# 80
# Getting page: 9
# 90
# Getting page: 10
# 100
# Getting page: 11
# 110
# Getting page: 12
# 120
# Getting page: 13
# 130
# Getting page: 14
# 140
# Getting page: 15
# 150
# Getting page: 16
# 160
# Getting page: 17
# 170
# Getting page: 18
# 180
# Getting page: 19
# 190
# Fin.

# %%
corpus = pd.read_csv('headphones21.csv')
corpus
# Out:
#                                                product  \
# 0    Amazon.in:Customer reviews: boAt Airdopes 141 ...
# 1    Amazon.in:Customer reviews: boAt Airdopes 141 ...
# 2    Amazon.in:Customer reviews: boAt Airdopes 141 ...
# 3    Amazon.in:Customer reviews: boAt Airdopes 141 ...
# 4    Amazon.in:Customer reviews: boAt Airdopes 141 ...
# ..                                                 ...
# 185  Amazon.in:Customer reviews: boAt Airdopes 141 ...
# 186  Amazon.in:Customer reviews: boAt Airdopes 141 ...
# 187  Amazon.in:Customer reviews: boAt Airdopes 141 ...
# 188  Amazon.in:Customer reviews: boAt Airdopes 141 ...
# 189  Amazon.in:Customer reviews: boAt Airdopes 141 ...
#
#                                       date  \
# 0        Reviewed in India on 19 July 2021
# 1        Reviewed in India on 20 July 2021
# 2        Reviewed in India on 20 July 2021
# 3     Reviewed in India on 19 January 2022
# 4     Reviewed in India on 23 January 2022
# ..                                     ...
# 185     Reviewed in India on 20 April 2022
# 186  Reviewed in India on 17 December 2021
# 187     Reviewed in India on 22 April 2022
# 188  Reviewed in India on 27 November 2021
# 189  Reviewed in India on 27 December 2021
#
#                                                  title  rating  \
# 0        Must have travelled to future and returned :D     2.0
# 1                                      Value for Money     4.0
# 2                                         First review     4.0
# 3                Good choice (w/ some problems) @999/-     4.0
# 4    Just because it's a brand doesn't mean the pro...     1.0
# ..                                                 ...     ...
# 185            Low quality product not worth the money     1.0
# 186                              Very very bad product     1.0
# 187                      A good product, worth buying!     4.0
# 188    No Noise cancellation and sound quality is poor     2.0
# 189            Good if you don’t prefer premium sound.     4.0
#
#                                                   body
# 0    I ordered this Yesterday ,18th July and receiv...
# 1    Pros:1. As soon as you open the case it connec...
# 2                       The media could not be loaded.
# 3    My review is a little bit long(sorry!) but I h...
# 4    I don't know what to say. I bought it a week a...
# ..                                                 ...
# 185  The product is a cheep product which cant sust...
# 186  Very very bad product....it looked like it's a...
# 187  I am writing this review after using the produ...
# 188  Bought this item based on the product review r...
# 189  You can go for it if you’re on a budget and do...
#
# [190 rows x 5 columns]
